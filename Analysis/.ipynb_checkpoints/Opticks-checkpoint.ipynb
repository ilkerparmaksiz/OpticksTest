# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#hit=np.load("/tmp/argon/opticks/GEOM/B1/exampleB1/ALL0/A000/hit.npy")
photon=np.load("/tmp/argon/opticks/GEOM/B1/exampleB1/ALL0/A000/photon.npy")

# %%
print(photon)
# Out:
# [[[ 2.7564337e+00  2.9230921e-03  1.4999998e+02  3.0854721e+01]
#   [ 1.8373126e-02  1.9483879e-05  9.9983120e-01  0.0000000e+00]
#   [ 9.9982762e-01  2.6508570e-03 -1.8373113e-02  1.9970073e+02]
#   [ 1.8385036e-40  0.0000000e+00  0.0000000e+00  1.8216880e-43]]
#
#  [[ 2.7564337e+00  2.9230921e-03  1.4999998e+02  3.0854721e+01]
#   [ 1.8373126e-02  1.9483879e-05  9.9983120e-01  0.0000000e+00]
#   [ 9.9982762e-01  2.6508570e-03 -1.8373113e-02  1.9970073e+02]
#   [ 1.8385036e-40  0.0000000e+00  1.4012985e-45  1.8216880e-43]]
#
#  [[ 2.7564337e+00  2.9230921e-03  1.4999998e+02  3.0854721e+01]
#   [ 1.8373126e-02  1.9483879e-05  9.9983120e-01  0.0000000e+00]
#   [ 9.9982762e-01  2.6508570e-03 -1.8373113e-02  1.9970073e+02]
#   [ 1.8385036e-40  0.0000000e+00  2.8025969e-45  1.8216880e-43]]
#
#  ...
#
#  [[ 3.5231979e+00 -1.2076902e+00  1.4999998e+02            nan]
#   [ 1.8373126e-02  1.9483879e-05  9.9983120e-01  0.0000000e+00]
#   [ 9.9982762e-01  2.6508570e-03 -1.8373113e-02  1.9970073e+02]
#   [ 1.8385036e-40  0.0000000e+00  1.4923787e-39  1.8216880e-43]]
#
#  [[ 3.5231979e+00 -1.2076902e+00  1.4999998e+02            nan]
#   [ 1.8373126e-02  1.9483879e-05  9.9983120e-01  0.0000000e+00]
#   [ 9.9982762e-01  2.6508570e-03 -1.8373113e-02  1.9970073e+02]
#   [ 1.8385036e-40  0.0000000e+00  1.4923801e-39  1.8216880e-43]]
#
#  [[ 3.5231979e+00 -1.2076902e+00  1.4999998e+02            nan]
#   [ 1.8373126e-02  1.9483879e-05  9.9983120e-01  0.0000000e+00]
#   [ 9.9982762e-01  2.6508570e-03 -1.8373113e-02  1.9970073e+02]
#   [ 1.8385036e-40  0.0000000e+00  1.4923815e-39  1.8216880e-43]]]

# %% [raw]
# xHit = hit[:,0,0]
# yHit = hit[:,0,1]
# zHit = hit[:,0,2]

# %%
xphoton = photon[:,0,0]
yphoton = photon[:,0,1]
zphoton = photon[:,0,2]

# %%
print(photon[3])
# Out:
# [[ 2.7564337e+00  2.9230921e-03  1.4999998e+02  3.0854721e+01]
#  [ 1.8373126e-02  1.9483879e-05  9.9983120e-01  0.0000000e+00]
#  [ 9.9982762e-01  2.6508570e-03 -1.8373113e-02  1.9970073e+02]
#  [ 1.8385036e-40  0.0000000e+00  4.2038954e-45  1.8216880e-43]]

# %% [raw]
# #print(len(xHit))
# print(len(xphoton))

# %% [raw]
# plt.figure(figsize=(15,15),dpi=300)
# bins=np.arange(-1,100,1)
# plt.hist(xHit,label="XPosition",bins=bins,alpha=0.5)
# plt.hist(yHit,label="YPosition",bins=bins,alpha=0.5)
# plt.hist(zHit,label="ZPosition",bins=bins,alpha=0.5)
# plt.xlabel("mm")
# plt.ylabel("Photons")
# plt.legend()
# plt.show()

# %%
print(zphoton)
print(yphoton)
print(xphoton)
# Out:
# [149.99998 149.99998 149.99998 ... 149.99998 149.99998 149.99998]
# [ 0.00292309  0.00292309  0.00292309 ... -1.2076902  -1.2076902
#  -1.2076902 ]
# [2.7564337 2.7564337 2.7564337 ... 3.523198  3.523198  3.523198 ]

# %%
plt.figure(figsize=(15,15),dpi=300)
alls=np.array([])
alls=np.append(alls,xphoton)
alls=np.append(alls,yphoton)
alls=np.append(alls,zphoton)

step=2
bins=np.arange(np.min(alls),np.max(alls)+step,step)
plt.hist(xphoton,label="XPosition",bins=bins,alpha=0.5)
plt.hist(yphoton,label="YPosition",bins=bins,alpha=0.5)
plt.hist(zphoton,label="ZPosition",bins=bins,alpha=0.5)
plt.xlabel("mm")
plt.ylabel("Photons")
plt.legend()
plt.show()

# %% [raw]
# ### Hits
# fig = plt.figure()
# ax = fig.add_subplot(projection='3d')
# ax.scatter3D(xHit,yHit,zHit)
# ax.set_xlabel("X")
# ax.set_ylabel("Y")
# ax.set_zlabel("Z")
# plt.show()

# %%
## Root

# %%
import uproot

# %%
myfile=uproot.open("/home/argon/Projects/Ilker/OpticksTest/build/Opticks_CPU.root")

# %%
myfile.keys()
# Out:
# ['Photons;1', 'particles;1']

# %%
Photons=myfile["Photons"]
Particles=myfile["particles"]
Photons.keys()
# Out:
# ['Event', 'fx', 'fy', 'fz', 'ft', 'Volume']

# %%
PhotonVolume = Photons["Volume"].array()
mask=PhotonVolume=="Detector_Logic"

# %%
#print(np.count_nonzero(mask))

# %%
if(np.count_nonzero(mask)>0):
    PhotonFinalX=Photons["fx"].array()[mask]
    PhotonFinalY=Photons["fy"].array()[mask]
    PhotonFinalZ=Photons["fz"].array()[mask]
    PhotonFinalT=Photons["ft"].array()[mask]
else:
    PhotonFinalX=Photons["fx"].array()
    PhotonFinalY=Photons["fy"].array()
    PhotonFinalZ=Photons["fz"].array()
    PhotonFinalT=Photons["ft"].array()

# %%
alls=np.array([])
alls=np.append(alls,PhotonFinalX)
alls=np.append(alls,PhotonFinalY)
alls=np.append(alls,PhotonFinalZ)

step=1
bins=np.arange(np.min(alls),np.max(alls)+step,step)
plt.figure(figsize=(15,15),dpi=300)
plt.hist(PhotonFinalX,label="XPosition",bins=bins,alpha=0.5)
plt.hist(PhotonFinalY,label="YPosition",bins=bins,alpha=0.5)
plt.hist(PhotonFinalZ,label="ZPosition",bins=bins,alpha=0.5)
plt.xlabel("mm")
plt.ylabel("Photons")
plt.legend()
plt.show()

# %%
## Photons
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter3D(PhotonFinalX,PhotonFinalY,PhotonFinalZ,s=1)
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
plt.show()

# %%
## For  the Particle
Particles.keys()
# Out:
# ['Event', 'ID', 'name', 'x', 'y', 'z', 't', 'Volume']

# %%
PVolume=Particles["Volume"].array()
PName=Particles["name"].array()

# %%
print(PVolume)
print(PName)
PNameMask=PName=="alpha"
# Out:
# ['GasXe_Logic', 'GasXe_Logic', 'GasXe_Logic', ..., 'GasXe_Logic', 'GasXe_Logic']
# ['alpha', 'e-', 'e-', 'e-', 'e-', ..., 'alpha', 'alpha', 'alpha', 'alpha']

# %%
Px=Particles["x"].array()[PNameMask]
Py=Particles["y"].array()[PNameMask]
Pz=Particles["z"].array()[PNameMask]

# %%
## Alphas
fig = plt.figure()
ax.set_title("Root Alpha")
ax = fig.add_subplot(projection='3d')
#ax.scatter3D(xphoton,yphoton,zphoton,s=1,label="opticks")
ax.scatter3D(Px,Py,Pz,s=1,label="Geant4")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
ax.legend()
plt.show()

# %%
## Alphas
fig = plt.figure()
ax.set_title("Root Alpha")
ax = fig.add_subplot(projection='3d')
ax.scatter3D(xphoton,yphoton,zphoton,s=1,label="opticks")
#ax.scatter3D(Px,Py,Pz,s=1,label="Geant4")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
ax.legend()
plt.show()

# %%
## Photons
print(np.min(yphoton))
print(np.min(Py))
fig = plt.figure()
plt.scatter(Px,Pz,s=1,label="Geant4")


plt.xlabel("x")
plt.ylabel("Z")
plt.legend()
plt.show()
# Out:
# -1.2122508
# -1.2147782520696109

# %%
print(np.min(yphoton))
print(np.min(Py))
fig = plt.figure()

plt.scatter(xphoton,zphoton,s=1,label="Opticks")
plt.xlabel("x")
plt.ylabel("Z")
plt.legend()
plt.show()
# Out:
# -1.2122508
# -1.2147782520696109

# %%
print(np.min(yphoton))
print(np.min(Py))
fig = plt.figure()
plt.scatter(Px,Py,s=1,label="Geant4")

plt.scatter(xphoton,yphoton,s=1,label="Opticks")

plt.xlabel("Z")
plt.ylabel("Y")
plt.legend()
plt.show()
# Out:
# -1.2122508
# -1.2147782520696109
